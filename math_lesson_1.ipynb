# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10, 200)

# %%
k1 = 1

# %%
k2 = int(input("Введите значение k2: "))
# Out:
# Введите значение k2: 3

# %%
plt.plot(x, np.cos(k1*x))
plt.plot(x, np.cos(k2*x))
